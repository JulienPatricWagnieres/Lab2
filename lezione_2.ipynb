# %%
import numpy as np

# %%
a=[1,2,3]
ar=np.array(a)
ar.dtype
# Out:
# dtype('int64')

# %%
# %timeit
ar_primi=np.array([1,2,3,5,7])
len(ar_primi)
ar_primi.size
# Out:
# 5

# %%
def is_primo(a):
    for n in range(2,a):
        if a%n == 0:
            return False
    return True
# Out:
# True

# %%
ar_prime=np.array([x for x in range(10) if is_primo(x)])
ar_prime
# Out:
# array([0, 1, 2, 3, 5, 7])
